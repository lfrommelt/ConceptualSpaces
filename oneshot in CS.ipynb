# %%
import xml.etree.ElementTree as ET
import os
import sys
sys.path.append("conceptual_spaces")
import cs.cs as space
from cs.weights import Weights
from cs.cuboid import Cuboid
from cs.core import Core
from cs.core import from_cuboids
from cs.concept import Concept
import matplotlib.pyplot as plt
import visualization.concept_inspector as ci
import numpy as np
from matplotlib import patches
from sklearn.metrics import average_precision_score
from functools import reduce
from math import isnan
import random
import _pickle as pkl

C=0.05
#Get data from path to xml and add to given data
def xml_to_dict(path, data = {}, domain_mapping={}, dimension_names=[]):
    with open(os.path.normpath(path), 'rb') as xml_file:
        tree = ET.parse(xml_file)
        root = tree.getroot()
        newdata={}
        for exemplar in root:
            new_concept = get_domains(exemplar)
            if(new_concept):
                newdata[exemplar.attrib['name']] = new_concept

    n_old=len(dimension_names)
    domains={}
    for exemplar in newdata.values():
        domains.update(exemplar)
    del(domains['supercategory'])

    #domains = mapping: domain->dimension indices, also add new dimension names
    if domain_mapping:
        i=sum([len(domain) for domain in domain_mapping.values()])
    else:
        i=0
    for key in domains:
        if not key in domain_mapping:
            for dim in domains[key]:
                dimension_names+=[dim]
            domain_mapping[key]=list(range(i,i+len(domains[key])))
            i+=len(domains[key])

    #kick inconsistents
    to_del=[]
    for datum in newdata:
        if not is_consistent(newdata[datum], domain_mapping):
            print(datum ,'is inconsistent')
            to_del+=[datum]
    for kickit in to_del:
        del(newdata[kickit])

    #translate to point
    for datum in newdata:
        point=[]
        for domain in domain_mapping:
            if domain in newdata[datum]:
                point+=list(newdata[datum][domain].values())
            else:
                point+=[float('inf')]*len(domain_mapping[domain])     
        newdata[datum]={'supercategory':newdata[datum]['supercategory'], 'point':point}
    if len(dimension_names)>n_old and n_old:
        for datum in data:
            data[datum]['point']=data[datum]['point']+[float('inf') for _ in range(len(dimension_names)-n_old)]
    data.update(newdata)
    return domain_mapping, data, dimension_names

def less_dimensions(domain_mapping, data, dim_names,threshold=10):
    dimcounter={}
    for domain in domain_mapping:
        dimcounter[domain]=sum([1 if not datum['point'][domain_mapping[domain][0]] == float('inf') else 0 for datum in data.values()])


    for domain in dimcounter:
        if dimcounter[domain]<threshold:
            del(domain_mapping[domain])
    indices=[value for domain in domain_mapping.values() for value in domain]
    for concept in data.values():
        concept['point']=[value for value,i in zip(concept['point'],range(len(concept['point']))) if i in indices]

    dim_names=[value for value,i in zip(dim_names,range(len(dim_names))) if i in indices]
    i=0
    for domain in domain_mapping:
        if domain_mapping[domain][0]==i:
            i+=len(domain_mapping[domain])
        else:
            domain_mapping[domain]=[i+j for j in range(len(domain_mapping[domain]))]
            i+=len(domain_mapping[domain])
    return domain_mapping, data, dim_names
    
def family_into_space(name, values, add=True):
    cuboids=[]
    domains = {}
    for point in values:
        subdomains=point_to_domains(point)
        cuboids.append(Cuboid([dim if not dim==float('inf') else -dim for dim in point], point, subdomains))
        domains.update(subdomains)

    core=from_cuboids(cuboids,domains)
    weights=Weights(space._def_dom_weights,space._def_dim_weights)
    concept=Concept(core, 1.0, C, weights)
    if add:
        space.add_concept(name,concept)
    return concept
         
#Group data by their supercategories to form concepts
def form_supercategories(data):
    concepts={}
    for datum in data.values():
        if datum['supercategory'] in concepts:
            concepts[datum['supercategory']].append(datum['point'])
        else:
            concepts[datum['supercategory']]=[datum['point']]
        #del(concepts[datum['supercategory']])
    return concepts
    
#helper for xml_to_dict, important for how the data is supposed to look like
def get_domains(xml_elem):
    domains = xml_elem.find('genericPhysicalDescription')
    if(not(domains)):
        return
    domain_dict={}
    try:
        supercategory = xml_elem.find('family').text
        if supercategory in ['feline','rodent','primate','cetacean']:
            supercategory='mammal'
        elif supercategory in ['crustacean','arachnid']:
            supercategory = 'arthropod'
        elif supercategory in ['fruit', 'transport', 'furniture', 'book', 'building', 'musical_instrument', 'present', 'architectural_element', 'amphibian']:
            supercategory = 'object'
            return
        domain_dict['supercategory']=supercategory
    except AttributeError:
        domain_dict['supercategory']="object"
        return
        
    for domain in domains:
        domain_name=domain.tag
        if domain_name=='hasPart':
            domain_name=domain.get('name')
            if domain[0].tag=='number':
                domain_dict['n_'+domain_name]={'number_'+domain_name:float(domain[0].text)}
            else:
                pass
        else:
            numerical_domain={}
            for subelem in domain:
                try:
                    numerical_domain[subelem.tag]=float(subelem.text)
                except ValueError:
                    pass
            if numerical_domain:            
                if domain_name=='size' or domain_name=='location' or domain_name=='color' or domain_name=='locomotion':
                    domain_dict[domain_name]={key:value for key,value in zip(numerical_domain.keys(),numerical_domain.values())}
    return domain_dict

def domains_from_point(point):
    domains={}
    for domain in space._domains:
        if all(not point[dim]==float('inf') for dim in space._domains[domain]):
            domains[domain]=space._domains[domain]
    return domains

def point_to_concept2(point, name=None, size=1000000, weights=[]):
    domains = domains_from_point(point)
    p_min=[-size for value in point]
    p_max=[size for value in point]
    c_example = Cuboid(p_min, p_max, domains)
    s_example = Core([c_example], domains)
    if not weights:
        weights=space._def_dom_weights
    w_example = Weights(weights,space._def_dim_weights)
    concept = Concept(s_example, 1.0, C, w_example)
    #space.add_concept(name, concept)
    return concept

def point_to_concept(point, name, weights=[]):
    domains = domains_from_point(point)
    p_min=[value if not value==float('inf') else float('-inf') for value in point]
    c_example = Cuboid(p_min, point, domains)
    s_example = Core([c_example], domains)
    if not weights:
        weights=space._def_dom_weights
    w_example = Weights(weights,space._def_dim_weights)
    concept = Concept(s_example, 1.0, C, w_example)
    #space.add_concept(name, concept)
    return concept

#gives all permutations of a binary vector of given length with -1 and 1 as elements
def get_permutations(length):
    if length==1:
        #positive first, because later on earlier permutations are preferred
        return [[[1]],[[-1]]]
    else:
        new_vectors=[]
        for vector in get_permutations(length-1):
            new_vectors+=[vector+[[1]],vector+[[-1]]]
        return new_vectors
    
def evaluate_signs(signs):
    #max(evaluate_signs) -> maximize cumulative similarity of columns
    value=0
    for dimension in signs.T:
        value+=abs(sum(dimension))
    return value

#'brushes' all vectors to point in the most common general direction
def brush_vectors(pc1s):
    signs=np.zeros(pc1s.shape)
    for j in range(len(signs)):
        for i in range(len(signs[j])):
            if pc1s[j,i]>0:
                signs[j,i]=1
            elif pc1s[j,i]<0:
                signs[j,i]=-1
    permutations=get_permutations(len(signs))
    signs_x_perms=np.array([perm*signs for perm in permutations])
    return pc1s*permutations[np.argmax([evaluate_signs(brushed_pc1s) for brushed_pc1s in signs_x_perms])]

def brush_to_size(pc1s):
    indices=[space._dim_names.index('x'),space._dim_names.index('y'),space._dim_names.index('z')]
    newpc1s=[]
    for pc1 in pc1s:
        if sum(pc1[indices])>0:
            newpc1s.append(pc1)
        else:
            newpc1s.append(-pc1)
    return np.array(newpc1s)


#We do not want any concepts with partially filled domains. This would go against the very idea of domains. input: {doms:values}. Also concepts with only undefined dims are not needed
def is_consistent(concept, domain_mapping={}):
    inf_check=[]
    for domain in concept:
        if not domain=='supercategory':
            if not(len(concept[domain])==len(domain_mapping[domain])):
                return False
            inf_check+=concept[domain]
    if all([check==float('inf') for check in inf_check]):
        return False
    return True

#normalize by data with missing values replaced my mean
def normalize_to_standard_score(points):
    #calculate means af defined values for each dimension
    means=[]
    for dimension in zip(*points):
        values=[x for x in dimension if not (x==float('inf') or np.isnan(x))]
        if len(values):
            means.append(sum(values)/len(values))
        else:
            means.append(0)
    means=np.array(means)
    
    #copy data, replace missing values by mean
    normalized_data=np.zeros(np.shape(points))
    for j in range(len(points)):
        for i in range(len(points[j])):
            normalized_data[j][i]=points[j][i] if not (points[j][i]==float('inf') or np.isnan(points[j][i])) else means[i]
            
    #calculate the std in each dimension
    stds=np.std(normalized_data, axis = 0)
    #stds of 0 zero are considered to be inf, in order to avoid division by zero
    stds=np.array([std if not std==0 else float('inf') for std in stds])
    #normalize data to standard score
    normalized_data = [(point-means)/stds for point in normalized_data]
    #for the inverse function a std of zero is ok again, inverse fun not implemented, only "amount" of one std
    stds=np.array([std if not std==float('inf') else 0 for std in stds])
    #inverse_fun = lambda x:x*stds+means
    return stds, np.array(normalized_data)

def point_to_domains(point):
    domains={}
    for dim in range(space._n_dim):
        if not(point[dim]==float('inf') or point[dim]==float('-inf')):
            domains[space.dim_to_dom[str(dim)]]=space._domains[space.dim_to_dom[str(dim)]]
    return domains

def two_cubs_PCA(point, sibblings, learn_weights=False):
    #sibbling is list of sibbling names or dict with sibbling names as keys
    #We can play around with artificial_scaling to see the effect of arbitrary generalization (<1 does not really mean more specific, but rather just smaller/conservative)
    artificial_scaling=1
    n_dims=len(point)
    if sibblings==None:
        #not implemented for some reason
        sibblings=get_sibblings(supercategory)   
    variances=[]
    pc1s=[]
    #correlations=[]
    examples_x_stds=[]#Matrix examples x stds
    avg = np.average#lambda values: sum(values)/len(values)
    allcenters=[]
    for sibbling in sibblings:
        #centers of all cuboids of the sibbling concept
        centers = np.array([[(p_max+p_min)/2 for p_max,p_min in zip(cuboid._p_max, cuboid._p_min)] for cuboid in space._concepts[sibbling]._core._cuboids])
        #throw away concepts with less than 2 cuboids (not happening with dataset)
        if len(centers)>1:
            allcenters.append(centers)
            #Centers are translated to data cloud that has std=1 in every dimension. stds remembers the multiplicative(eng?) part of the reverse operation
            #as simpler version compared to regression
            stds, data=normalize_to_standard_score(centers)
            examples_x_stds.append(stds)
            #np.cov input: rows=dimensions, columns=observations!! (very likely to produce error down the line if done wrong though)
            #np.linalg.eig output: values=eigenvalues, vectors=eigenvectors in columns!! (no error when done wrong because square matrix!)
            values, vectors = np.linalg.eig(np.cov(data.T))
            #the first PC has unit length so multiplying it with std lets it have (euclidean) length=std (in direction of largest var)
            pc1s.append(np.array(vectors[:,np.argmax(values)])*(max(values)**(1/2)))
        
    #The sign of a whole PC is only meaningfull in relation to the other PCs, so we assume that all first PCs point in a somewhat similar direction. Size is ignored.
    pc1s=brush_vectors(np.array(pc1s))
    #makes signs point in a direction so that the size dimension still correlate with each other over all examples
    pc1s=brush_to_size(pc1s)
    
    #A dimension of a PC that is zero because the original values where all undefined is considered uninformative, since examples
    #that have an undefined value lead to a concept with no variance in that dimension anyways
    meanpc=[]
    for dimension, dimindex in zip(pc1s.T, range(len(pc1s.T))):
        #all meaningfull values of the 1st PCs of all known concepts in a single dimension
        cleanvalues=[]
        for value, conceptindex in zip(dimension, range(len(dimension))):
            #print([np.isnan(examplevalue[dimindex]) for examplevalue in allcenters[conceptindex]])
            #print(conceptindex)
            if not value==0:
                cleanvalues.append(value)
            #a variance of 0 in a certain dimension in the first PC can be due to all known examples of a category being undefined in that dimension
            #the other way round this implies that some values have not been included because of the wrong reasons beforehand
            elif not all([np.isnan(examplesvalues[dimindex]) for examplesvalues in allcenters[conceptindex]]):
                cleanvalues.append(value)

        if len(cleanvalues):
            #quite some information is lost in this step (PCs canceling out each other because of wrong reasons), but we need to generalize
            meanpc.append(sum(cleanvalues)/len(cleanvalues))
        else:
            #Should not happen, since uninformative dimensions have already been kicked out. If it happens anyways, zero  is actually the correct value
            #(i.e. no variance in dim with only undefined values)
            meanpc.append(0)

    meanstds=np.average(examples_x_stds, axis=0)

    
    #for some reason i=0 happens quite often, although the docu promises that real values are used in these cases
    meanpc=[np.real(val) for val in meanpc]
    
    #We have our background knowledge. Nice! Multiplying with the mean 'size' in each dimension is improvable (multiplicative part of regression would be better)
    learnt_vector=meanstds*meanpc
    
    #start building our new concept
    cub1=np.zeros(n_dims)
    cub2=np.zeros(n_dims)
    
    for dim in range(n_dims):
        #point as central region, multiply by two to reverse taking center of cuboids
        cub1[dim]=point[dim]-learnt_vector[dim]*2*artificial_scaling
        cub2[dim]=point[dim]+learnt_vector[dim]*2*artificial_scaling

    c1_p_min=[cub1[dim] if cub1[dim] < point[dim] else float('-inf') if point[dim]==float('inf') else point[dim] for dim in range(n_dims)]
    c1_p_max=[cub1[dim] if cub1[dim] > point[dim] else point[dim] for dim in range(n_dims)]
    
    c2_p_min=[cub2[dim] if cub2[dim] < point[dim] else float('-inf') if point[dim]==float('inf') else point[dim] for dim in range(n_dims)]
    c2_p_max=[cub2[dim] if cub2[dim] > point[dim] else point[dim] for dim in range(n_dims)]
    
    domains = domains_from_point(c1_p_max)
    core=Core([Cuboid(c1_p_min, c1_p_max, domains),Cuboid(c2_p_min,c2_p_max,domains)],domains)
    
    if not learn_weights:
        dom_weights=space._def_dom_weights
    else:
        #dramatically improves performance, but seems unfair to compare to classes with meaningless weights
        dom_weights={}
        for domain in domain_mapping:
            variance=np.average([abs(meanpc[dim]) for dim in domain_mapping[domain]])+0.1            
            dom_weights[domain]=(1/variance)**100
        
    weights=Weights(dom_weights,space._def_dim_weights)
        
    concept=Concept(core, 1.0, C, weights)

    return concept

def one_shot(point, method=two_cubs_PCA, sibblings=None, name="newlearned", learn_weights=False):
    #right now unnecessary because by now only two_cubs_PCA is left over (actually naive_with_size, too), but cool python stuff
    return method(point, sibblings, learn_weights=learn_weights)
    
def naive_with_size(point, sibblings):
    #actually not bad for comparison, lets keep it for now
    learnt=two_cubs_pca(point,sibblings)
    size=learnt.size()
    print('size:',size)
    avg_dim_size=np.average([[np.average(cuboid._p_max[dimension]-cuboid._p_min[dimension]) for cuboid in learnt._core._cuboids] for dimension in range(len(learnt._core._cuboids[0]._p_min))])
    print(avg_dim_size)
    crisp_size=learnt.size_given_c(1000000000)
    print('crisp_size:',crisp_size)
    return avg_dim_size

def ap_balanced(concept, testdata={}, figure=None, target=None):
    class_size=len(testdata[target])-(len(testdata[target])%(len(testdata)-1))
    balanced_data={target:testdata[target][20:class_size+21]}
    for family in testdata:
        if not family==target:
            balanced_data[family]=testdata[family][:int(class_size/(len(testdata)-1))]
    return average_precision(concept,testdata=balanced_data, target=target)
    
def average_precision(concept, testdata={}, figure=None, target=None):#old signature!
    """Average Precision of the concept as a classifier

    Parameters:
    negatives (list): list of points that do not belong to the target class
    positives (list):...

    Returns:
    ap (float)

   """
    negatives=[point for family in testdata for point in testdata[family] if not family==target]
    positives=[point for family in testdata for point in testdata[family] if family==target]
    #negatives=reduce(lambda x,y:x+y, list(negatives.values()))
    y_true=np.concatenate((np.ones(len(positives)),np.zeros(len(negatives))))
    y_scores=np.zeros(len(y_true))
    for i in range(len(y_scores)):
        if i < len(positives):
            y_scores[i]=concept.membership_of(positives[i])
        else:
            y_scores[i]=concept.membership_of(negatives[i-len(positives)])
    sorted_truths=[[y,x] for y,x in sorted(zip(y_scores,y_true),reverse=True)]
    recalls=[]
    precisions=[]
    i=0
    while i < len(sorted_truths):
        j=0
        if i+1<len(sorted_truths):
            while sorted_truths[i][0]==sorted_truths[i+j+1][0]:
                if i+j+2<len(sorted_truths):
                    j+=1
                else:
                    break
        tp=sum([truth[1] for truth in sorted_truths[:i+1+j]])
        t=len(positives)
        p=i+j+1
        recalls.append(tp/t)
        precisions.append(tp/p)
        for _ in range(j):
            i+=1
        i+=1

    #plt.subplots(figsize=(10, 10))
    if figure=='part':
        plt.scatter(recalls, precisions, color = color)#[(0.5,x,x) for x in [(len(recalls)-i)/len(recalls) for i in range(len(recalls))]])
    elif figure=='developement':
        plt.scatter(recalls, precisions, color = [(0.5,x,x) for x in [(len(recalls)-i)/len(recalls) for i in range(len(recalls))]])
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.show()
    #plt.figure(figsize=(10,20))
    #plt.show()
    ap=average_precision_score(y_true, y_scores)
    '''print(y_true)
    print(y_scores)
    print(ap)'''
    return ap

#normalizes values to sum(values)=1
def normalize(values):
    if not sum(values):
        return([1/len(values) for _ in values])
    summed=sum(values)
    for i in range(len(values)):
        values[i]=values[i]/summed
    
def log(x):
    #in information theory log means log_2 since naturalis already has ln(x) as notation
    return np.log2(x)
     
def categorical_cross_entropy(concept, testdata, target, figure=None):
    '''compute the categorical cross entropy from a classifier consisting of our existing concepts, where one can be replaced
    with the concept parameter (concept for target), to a theoretical perfect classifier'''
    #Since officially there is no ordering in dictonaries, this:
    indices={family:index for family,index in zip(testdata,range(len(testdata)))}
    
    predictions=[]
    for family in indices:
        i=0
        for testdatum in testdata[family]:
            i+=1
            #absolute certainty of each class for the example
            all_predictions=[space._concepts[conc].membership_of(testdatum) if not conc==target else concept.membership_of(testdatum) for conc in indices]
            #relative certainty of each class for the example, with assumed equipropable a priori propabilities
            normalize(all_predictions)
            #only the prediction for the class from which the example was drawn is relevant, all others would be multiplied by zero down the line
            pred_target=all_predictions[indices[family]]
            predictions.append(pred_target)

    cross_entropies=[]
    #iterate through examples
    for pred in predictions:
        #might be inf
        cross_entropies.append(-log(pred))

    #annoying but really informative, regarding individual examples
    print('score:',np.median(cross_entropies))
    
    #median because mean is too susceptible for inf values
    return np.median(cross_entropies)

def sample_data(n, a=2):
    '''Crisp sampling with n examples drawn per class, n%10=0
    Returns: testdata (dict): {class: point (list)}
    '''
    domain_mapping, data, dim_names = xml_to_dict("Dataset\\prototypes.xml")
    domain_mapping, data, dim_names = xml_to_dict("Dataset\\exemplars.xml", domain_mapping=domain_mapping, data=data, dimension_names=dim_names)
    domain_mapping, data, dim_names = less_dimensions(domain_mapping, data, dim_names)
    space.init(len(dim_names), domain_mapping, dim_names)

    concepts=form_supercategories(data)

    random.seed(a=a)

    testdata={}
    families={}
    i=1
    for concept in concepts:
        print(concept)
        families[concept]=family_into_space(concept, concepts[concept],add=False)
        conc=families[concept]
        testdata[concept]=[]
        for j in range(int(n/10)):
            testdata[concept]+=conc.crisp_sample(10)
            print(i,j*10)
        i+=1
        
    #no examples without information
    for family in testdata:
        for i in range(n):
            while all([value==float('inf') for value in testdata[family][i]]):
                testdata[family][i]=families[family].crisp_sample(1)[0]
    
    return testdata
    
def serialize_testdata(testdata, path='testdata.pkl'):
    with open(path, 'wb') as file:
        pkl.dump(testdata,file)
        
def deserialize_testdata(path):
    with open(path, 'rb') as file:
        data=pkl.load(file)
    return data
    
def evaluate_example(example, data, concepts, domains, dim_names, figure=None, method=two_cubs_PCA, testdata={}, criterion=average_precision, learn_weights=False):
    """Look what would happen, if example was a OSL input

    Parameters:
    example (dict): {'target': name of target class (str), 'point': values of the datum (list), 'n': count of examples from target, used for naming (int)}
    or
    example (str): name of traindatum (e.g. 'Rhinozeros')

    concepts (dict): returned from form_supercategories, {class: traindata for class} 

    Returns:
    aps (dict): complete evaluation, ordered by inputs

    """
    space.init(len(dim_names), domains,dim_names)
    
    #translate traindata into concepts, and put them into space
    classes={name:family_into_space(name, values) for name,values in zip(concepts,concepts.values())}

    if isinstance(example,dict):
        target=example['target']
        examplename='some'+target+str(example['n'])
        example=example['point']
    else:
        #example taken from trainset (ok because of leave-one-out evaluation, but unbalanced)
        target=data[example]['supercategory']
        examplename=example
        example=data[example]['point']
        testdata=list(concepts[target])
        testdata.remove(data[examplename]['point'])
    
    sibblings = [concept for concept in space._concepts if not concept==target]
    learnt_category=one_shot(example, method,sibblings=sibblings,name=target+'from'+examplename,learn_weights=learn_weights)
    
    #start cheating
    centers = np.array(concepts[target]).T
    means=[]
    for dimension in range(len(centers)):
        means.append(np.average([value for value in centers[dimension] if not value==float('inf')]))
    means=[mean if not np.isnan(mean) else float('inf') for mean in means]
    cheated=one_shot(means, method,sibblings=sibblings,name=target+'cheatedfrom'+examplename,learn_weights=learn_weights)
    target_dict={}
    known=space._concepts[target]
        
    if not learn_weights:
        weights=space._def_dom_weights
    else:
        weights=learnt_category._weights
        known._weights=weights

    #A size of 100000 entails all examples we have in our data
    naive_big=point_to_concept2([0 for _ in example],'naive_big', 100000,weights)
    
    print('\n\nExample:',examplename)
    print('\nlearnt')
    eval_learnt=criterion(learnt_category, testdata=testdata, figure=figure, target=target)
    print('\nnaiveBig')
    ap_naive=criterion(naive_big, testdata=testdata, figure=figure, target=target)
    
    print('\nnaiveSmall')
    naive_small=point_to_concept(example,'naive',weights=weights)
    ap_naive2=criterion(naive_small, testdata=testdata,figure=figure, target=target)

    
    print('\nknown')
    ap_known=criterion(known, testdata=testdata, figure=figure, target=target)
    
    print('\ncheated:')
    ap_cheated=criterion(cheated, testdata=testdata, figure=figure, target=target)
    
    print('\ncheated2')
    ap_cheated2=criterion(cheated2, testdata=testdata, figure=figure, target=target)
    
    return {examplename:[eval_learnt, ap_naive, ap_naive2, ap_known, ap_cheated]}

def print_evaluation(aps):
    diff_ap=[x[0] for x in aps.values()]
    print('learnt')
    print('max',max(diff_ap),'(',list(aps.keys())[np.argmax(diff_ap)],')')
    print('min',min(diff_ap),'(',list(aps.keys())[np.argmin(diff_ap)],')')
    print('avg',sum(diff_ap)/len(diff_ap))

    diff_ap=[x[1] for x in aps.values()]
    print('naive big')
    print('max',max(diff_ap))
    print('min',min(diff_ap))
    print('avg',sum(diff_ap)/len(diff_ap))

    diff_ap=[x[2] for x in aps.values()]
    print('naive small')
    print('max',max(diff_ap),'(',list(aps.keys())[np.argmax(diff_ap)],')')
    print('min',min(diff_ap),'(',list(aps.keys())[np.argmin(diff_ap)],')')
    print('avg',sum(diff_ap)/len(diff_ap))

    diff_ap=[x[3] for x in aps.values()]
    print('known')
    print('max',max(diff_ap))
    print('min',min(diff_ap))
    print('avg',sum(diff_ap)/len(diff_ap))

    diff_ap=[x[4] for x in aps.values()]
    print('cheated')
    print('max',max(diff_ap))
    print('min',min(diff_ap))
    print('avg',sum(diff_ap)/len(diff_ap))
    
def evaluate_on_dataset(testdata, criterion):
    #read concepts from prototypes and exemplars
    domain_mapping, data, dim_names = xml_to_dict("Dataset\\prototypes.xml")
    domain_mapping, data, dim_names = xml_to_dict("Dataset\\exemplars.xml", domain_mapping=domain_mapping, data=data, dimension_names=dim_names)
    domain_mapping, data, dim_names = less_dimensions(domain_mapping, data, dim_names,threshold=10)
    space.init(len(dim_names), domain_mapping, dim_names)

    concepts=form_supercategories(data)

    aps={}
    for target in testdata:
        n=0
        if len(concepts[target])-1:
            for example in testdata[target]:

                n+=1
                ex={'target':target,'point':example,'n':n}
                #print(ex['target'],ex['n'])
                aps.update(evaluate_example(ex, data, concepts, domain_mapping, dim_names, method=two_cubs_PCA, testdata=testdata, criterion=criterion))
    return aps

def get_certainties(traindata, testdata, domains, dim_names, params={}):
    try:
        C=params['C']
    except Exception:
        C=0.5
    try:
        weights=params['weights']
    except Exception:
        weights=False
    try:
        scaling=params['scaling']
    except Exception:
        scaling=1
    try:
        multiclass=params['multiclass']
    except Exception:
        multiclass=True
    try:
        classifiers=params['classifiers']
    except Exception:
        classifiers=['learnt','known','naive_small','naive_big','cheated']
        
    n_classes=len(testdata)
    indexed_classes=np.array(list(testdata.keys()))
    
    space.init(len(dim_names),domains,dim_names)
    if weights:
        dom_weights, dim_weights=normalize_weights()
        space.def_dom_weights=dom_weights
        space.def_dim_weights=dim_weights
        for concept in space._concepts.values():
            concept._weights=Weights(dom_weights,dim_weights)
    for concept in traindata:
        family_into_space(concept, traindata[concept], add=True)
    #ci.init()
    classifier_dict={}
    if 'naive_big' in classifiers:
        classifier_dict['naive_big']=point_to_concept2([0 for _ in dim_names])
        
    all_certainties=[]
    for target in testdata:
        known=False
        if 'known' in classifiers:
            classifier_dict['known']=space._concepts[target]
        if 'cheated' in classifiers:
            
            centers = np.array(traindata[target]).T
            means=[]
            for dimension in range(len(centers)):
                means.append(np.average([value for value in centers[dimension] if not value==float('inf')]))
            means=[mean if not np.isnan(mean) else float('inf') for mean in means]

            #midpoint=np.average([[(c._p_max[i]+c._p_min[i])/2 for i in range(space._n_dim)] for c in space._concepts[target]._core._cuboids], axis=0)
            classifier_dict['cheated']=one_shot(means, sibblings=[family for family in traindata if not family==target])
        for datum in testdata[target]:
            classifier_dict['naive_small']=point_to_concept(datum, 'naive_small')
            classifier_dict['learnt']=one_shot(datum, sibblings=[family for family in traindata if not family==target])

            default_certainties={conc:space._concepts[conc].membership_of(datum) for conc in indexed_classes}
            certainties={}#np.zeros((len(classifiers),n_classes))4
            
            for i,classifier in zip(range(len(classifiers)),classifiers):
                #print(classifier)
                #print(classifier_dict[classifier])
                absolute_certainties=[default_certainties[conc] if not(conc==target) else classifier_dict[classifier].membership_of(datum) for conc in indexed_classes]
                #print(absolute_certainties)
                #print([absolute/sum(absolute_certainties) for absolute in absolute_certainties])
                certainties[classifier]=[absolute/sum(absolute_certainties) for absolute in absolute_certainties]
            print(certainties)    
            all_certainties.append(certainties)
    return all_certainties
            
#def one_shot(point, method=None, sibblings=None, name="newlearned", learn_weights=False):


'If you see this, the cell has succesfully finished running'
# Out:
# 'If you see this, the cell has succesfully finished running'

# %%
domain_mapping, data, dim_names = xml_to_dict("Dataset\\prototypes.xml")
domain_mapping, data, dim_names = xml_to_dict("Dataset\\exemplars.xml", domain_mapping=domain_mapping, data=data, dimension_names=dim_names)
domain_mapping, data, dim_names = less_dimensions(domain_mapping, data, dim_names)
concepts=form_supercategories(data)

#family_into_space(concept, traindata[concept], add=false)

testdata=deserialize_testdata('testdata.pkl')
for family in testdata:
    print(family)
    testdata[family]=testdata[family][:5]

get_certainties(concepts, testdata, domain_mapping, dim_names, params={})
# Out:
# owl is inconsistent
# bat is inconsistent
# salmon is inconsistent
# spider is inconsistent
# Sea_Turtle_Dermochelys_Choriacea is inconsistent
# Sockeye_Salmon is inconsistent
# Golden_Trout is inconsistent
# thin_leg_spider is inconsistent
# little_brown_bat is inconsistent
# trachemys_turtle is inconsistent
# mammal
# bird
# insect
# arthropod
# reptile
# fish
# mollusk
# learnt
# core: {[-inf, -inf, -inf, -inf, -inf, -inf, 191.04476406087835, 324.2953025372939, 11135.995803388058, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 204.1255522266538, 339.4547820221276, 11153.490030461366, inf, inf, inf, inf, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, 204.1255522266538, 339.4547820221276, 11153.490030461366, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 217.20634039242927, 354.61426150696127, 11170.984257534674, inf, inf, inf, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# [1.0, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# known
# core: {[4.0, 10.0, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 100.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 600.0, 80.0, 150.0, 250.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, 72.20408163265306, 124.12244897959184, 370.40816326530614, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 600.0, 500.0, 12000.0, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 0.0, 26.05263157894737, 303.94736842105266, 0.0, 72.20408163265306, 124.12244897959184, 300.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 51.31578947368421, 50.0, 450.0, 47.36842105263158, 90.0, 250.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [1.0, 25.29268292682927, 51.31578947368421, 26.05263157894737, 0.0, 0.0, 60.0, 80.0, 250.0, 48.266666666666666, 0.0, 0.0, -inf, -inf, -inf, 1.0, -inf]-[4.780487804878049, 30.0, 100.0, 30.0, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, inf, inf, inf, 1.0, inf], [4.0, 10.0, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 250.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 200.0, 550.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 300.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 55.0, 70.0, 30.0, 303.94736842105266, 60.0, 100.0, 200.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [4.0, 2.0, 51.31578947368421, 26.05263157894737, 200.0, 47.36842105263158, 30.0, 70.0, 20.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 303.94736842105266, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 10.0, 303.94736842105266, 47.36842105263158, 20.0, 55.0, 80.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, 1.0, 2.0]-[5.0, 40.0, 60.0, 26.05263157894737, 800.0, 60.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, 1.0, 2.0], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 70.0, 100.0, 200.0, 0.0, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 70.0, 30.0, 500.0, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 48.266666666666666, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.0, 3.0, 51.31578947368421, 26.05263157894737, 10.0, 40.0, 72.20408163265306, 124.12244897959184, 350.0, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 90.0, 40.0, 303.94736842105266, 47.36842105263158, 120.0, 150.0, 370.40816326530614, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 100.0, 200.0, 48.266666666666666, -20.0, 26.8, 3.8536585365853657, -inf, -inf, 1.0, -inf]-[5.0, 40.0, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 80.0, 12.266666666666667, 94.0, 4.0, inf, inf, 1.0, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 120.0, 200.0, 48.266666666666666, 12.266666666666667, 26.8, 3.853658536585365 ...
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# [1.0, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# naive_small
# core: {[-inf, -inf, -inf, -inf, -inf, -inf, 204.1255522266538, 339.4547820221276, 11153.490030461366, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 204.1255522266538, 339.4547820221276, 11153.490030461366, inf, inf, inf, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# [1.0, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# naive_big
# core: {[-1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000]-[1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# [1.0, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# cheated
# core: {[4.767441860465116, 24.613767348596852, 47.359703840769335, 26.5, 304.0, 48.5, 58.17921183422456, 107.48052051516632, 346.7057729266914, 36.18272741059545, 13.734493333219666, 19.668325819986578, 3.857142857142857, 2.0, -inf, 1.0, 2.0]-[4.873442290738899, 24.88372093023256, 52.25, 29.54149204315426, 507.7231478063112, 62.69060983494555, 71.26, 122.64, 364.2, 48.369565217391305, 13.73913043478261, 27.67391304347826, 3.857142857142857, 2.0, inf, 1.0, 2.0], [4.661441430191333, 24.88372093023256, 52.25, 23.45850795684574, 100.2768521936888, 34.30939016505445, 71.26, 122.64, 364.2, 48.369565217391305, 13.73913043478261, 27.67391304347826, 3.857142857142857, 2.0, -inf, 1.0, 2.0]-[4.767441860465116, 25.153674511868267, 57.140296159230665, 26.5, 304.0, 48.5, 84.34078816577545, 137.79947948483368, 381.6942270733086, 60.55640302418716, 13.743767536345553, 35.679500266969946, 3.857142857142857, 2.0, inf, 1.0, 2.0]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [8.35537952576394e-136, 4.253489271649507e-139, 1.2795705916018973e-140, 1.6200176121659114e-140, 7.402905656876395e-137, 7.558218526885455e-137, 1.2753818181956961e-139]
# [0.8476327588006777, 0.0004315060536436509, 1.2980929798524803e-05, 1.6434681317247847e-05, 0.07510066210314435, 0.07667627307422104, 0.00012938435719741893]
# learnt
# core: {[-inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, 38.264135031349255, 11.728061059962586, 53.73611980968078, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, inf, inf, inf, 50.45097283814511, 11.73269816152553, 61.74170703317246, inf, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, 50.45097283814511, 11.73269816152553, 61.74170703317246, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, inf, inf, inf, 62.63781064494097, 11.737335263088474, 69.74729425666415, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 0.7731467263187719, 1.0, 0.9323152638648505, 0.8036175702426922, 0.16295655360942132, 0.8231504250485282]
# [0.18197744387520703, 0.14069526499597437, 0.18197744387520703, 0.16966034860396467, 0.14624027128596978, 0.029654417088555637, 0.14979481027512137]
# known
# core: {[4.0, 10.0, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 100.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 600.0, 80.0, 150.0, 250.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, 72.20408163265306, 124.12244897959184, 370.40816326530614, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 600.0, 500.0, 12000.0, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 0.0, 26.05263157894737, 303.94736842105266, 0.0, 72.20408163265306, 124.12244897959184, 300.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 51.31578947368421, 50.0, 450.0, 47.36842105263158, 90.0, 250.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [1.0, 25.29268292682927, 51.31578947368421, 26.05263157894737, 0.0, 0.0, 60.0, 80.0, 250.0, 48.266666666666666, 0.0, 0.0, -inf, -inf, -inf, 1.0, -inf]-[4.780487804878049, 30.0, 100.0, 30.0, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, inf, inf, inf, 1.0, inf], [4.0, 10.0, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 250.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 200.0, 550.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 300.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 55.0, 70.0, 30.0, 303.94736842105266, 60.0, 100.0, 200.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [4.0, 2.0, 51.31578947368421, 26.05263157894737, 200.0, 47.36842105263158, 30.0, 70.0, 20.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 303.94736842105266, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 10.0, 303.94736842105266, 47.36842105263158, 20.0, 55.0, 80.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, 1.0, 2.0]-[5.0, 40.0, 60.0, 26.05263157894737, 800.0, 60.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, 1.0, 2.0], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 70.0, 100.0, 200.0, 0.0, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 70.0, 30.0, 500.0, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 48.266666666666666, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.0, 3.0, 51.31578947368421, 26.05263157894737, 10.0, 40.0, 72.20408163265306, 124.12244897959184, 350.0, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 90.0, 40.0, 303.94736842105266, 47.36842105263158, 120.0, 150.0, 370.40816326530614, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 100.0, 200.0, 48.266666666666666, -20.0, 26.8, 3.8536585365853657, -inf, -inf, 1.0, -inf]-[5.0, 40.0, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 80.0, 12.266666666666667, 94.0, 4.0, inf, inf, 1.0, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 120.0, 200.0, 48.266666666666666, 12.266666666666667, 26.8, 3.853658536585365 ...
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 0.7731467263187719, 1.0, 0.9323152638648505, 0.8036175702426922, 0.16295655360942132, 0.8231504250485282]
# [0.18197744387520703, 0.14069526499597437, 0.18197744387520703, 0.16966034860396467, 0.14624027128596978, 0.029654417088555637, 0.14979481027512137]
# naive_small
# core: {[-inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, 50.45097283814511, 11.73269816152553, 61.74170703317246, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, inf, inf, inf, 50.45097283814511, 11.73269816152553, 61.74170703317246, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 0.7731467263187719, 1.0, 0.9323152638648505, 0.8036175702426922, 0.16295655360942132, 0.8231504250485282]
# [0.18197744387520703, 0.14069526499597437, 0.18197744387520703, 0.16966034860396467, 0.14624027128596978, 0.029654417088555637, 0.14979481027512137]
# naive_big
# core: {[-1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000]-[1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 0.7731467263187719, 1.0, 0.9323152638648505, 0.8036175702426922, 0.16295655360942132, 0.8231504250485282]
# [0.18197744387520703, 0.14069526499597437, 0.18197744387520703, 0.16966034860396467, 0.14624027128596978, 0.029654417088555637, 0.14979481027512137]
# cheated
# core: {[4.767441860465116, 24.613767348596852, 47.359703840769335, 26.5, 304.0, 48.5, 58.17921183422456, 107.48052051516632, 346.7057729266914, 36.18272741059545, 13.734493333219666, 19.668325819986578, 3.857142857142857, 2.0, -inf, 1.0, 2.0]-[4.873442290738899, 24.88372093023256, 52.25, 29.54149204315426, 507.7231478063112, 62.69060983494555, 71.26, 122.64, 364.2, 48.369565217391305, 13.73913043478261, 27.67391304347826, 3.857142857142857, 2.0, inf, 1.0, 2.0], [4.661441430191333, 24.88372093023256, 52.25, 23.45850795684574, 100.2768521936888, 34.30939016505445, 71.26, 122.64, 364.2, 48.369565217391305, 13.73913043478261, 27.67391304347826, 3.857142857142857, 2.0, -inf, 1.0, 2.0]-[4.767441860465116, 25.153674511868267, 57.140296159230665, 26.5, 304.0, 48.5, 84.34078816577545, 137.79947948483368, 381.6942270733086, 60.55640302418716, 13.743767536345553, 35.679500266969946, 3.857142857142857, 2.0, inf, 1.0, 2.0]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [0.4702093016571424, 0.7731467263187719, 1.0, 0.9323152638648505, 0.8036175702426922, 0.16295655360942132, 0.8231504250485282]
# [0.09469724403421043, 0.155706967000506, 0.20139381271376852, 0.1877625256409854, 0.16184360643495047, 0.03281844163809698, 0.16577740253748224]
# learnt
# core: {[1.2665757719713333, 28.92144267850726, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[1.3725762022451156, 29.191396260142966, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf], [1.160575341697551, 29.191396260142966, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[1.2665757719713333, 29.461349841778674, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 0.8763440803008871, 0.5820830329762925, 0.36736824095718557, 1.0, 1.0, 0.7225526922492995]
# [0.18023382664931456, 0.15794684705410306, 0.10491105246095635, 0.066212183857141, 0.18023382664931456, 0.18023382664931456, 0.13022843667985579]
# known
# core: {[4.0, 10.0, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 100.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 600.0, 80.0, 150.0, 250.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, 72.20408163265306, 124.12244897959184, 370.40816326530614, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 600.0, 500.0, 12000.0, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 0.0, 26.05263157894737, 303.94736842105266, 0.0, 72.20408163265306, 124.12244897959184, 300.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 51.31578947368421, 50.0, 450.0, 47.36842105263158, 90.0, 250.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [1.0, 25.29268292682927, 51.31578947368421, 26.05263157894737, 0.0, 0.0, 60.0, 80.0, 250.0, 48.266666666666666, 0.0, 0.0, -inf, -inf, -inf, 1.0, -inf]-[4.780487804878049, 30.0, 100.0, 30.0, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, inf, inf, inf, 1.0, inf], [4.0, 10.0, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 250.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 200.0, 550.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 300.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 55.0, 70.0, 30.0, 303.94736842105266, 60.0, 100.0, 200.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [4.0, 2.0, 51.31578947368421, 26.05263157894737, 200.0, 47.36842105263158, 30.0, 70.0, 20.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 303.94736842105266, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 10.0, 303.94736842105266, 47.36842105263158, 20.0, 55.0, 80.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, 1.0, 2.0]-[5.0, 40.0, 60.0, 26.05263157894737, 800.0, 60.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, 1.0, 2.0], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 70.0, 100.0, 200.0, 0.0, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 70.0, 30.0, 500.0, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 48.266666666666666, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.0, 3.0, 51.31578947368421, 26.05263157894737, 10.0, 40.0, 72.20408163265306, 124.12244897959184, 350.0, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 90.0, 40.0, 303.94736842105266, 47.36842105263158, 120.0, 150.0, 370.40816326530614, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 100.0, 200.0, 48.266666666666666, -20.0, 26.8, 3.8536585365853657, -inf, -inf, 1.0, -inf]-[5.0, 40.0, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 80.0, 12.266666666666667, 94.0, 4.0, inf, inf, 1.0, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 120.0, 200.0, 48.266666666666666, 12.266666666666667, 26.8, 3.853658536585365 ...
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 0.8763440803008871, 0.5820830329762925, 0.36736824095718557, 1.0, 1.0, 0.7225526922492995]
# [0.18023382664931456, 0.15794684705410306, 0.10491105246095635, 0.066212183857141, 0.18023382664931456, 0.18023382664931456, 0.13022843667985579]
# naive_small
# core: {[1.2665757719713333, 29.191396260142966, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[1.2665757719713333, 29.191396260142966, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 0.8763440803008871, 0.5820830329762925, 0.36736824095718557, 1.0, 1.0, 0.7225526922492995]
# [0.18023382664931456, 0.15794684705410306, 0.10491105246095635, 0.066212183857141, 0.18023382664931456, 0.18023382664931456, 0.13022843667985579]
# naive_big
# core: {[-1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000]-[1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 0.8763440803008871, 0.5820830329762925, 0.36736824095718557, 1.0, 1.0, 0.7225526922492995]
# [0.18023382664931456, 0.15794684705410306, 0.10491105246095635, 0.066212183857141, 0.18023382664931456, 0.18023382664931456, 0.13022843667985579]
# cheated
# core: {[4.767441860465116, 24.613767348596852, 47.359703840769335, 26.5, 304.0, 48.5, 58.17921183422456, 107.48052051516632, 346.7057729266914, 36.18272741059545, 13.734493333219666, 19.668325819986578, 3.857142857142857, 2.0, -inf, 1.0, 2.0]-[4.873442290738899, 24.88372093023256, 52.25, 29.54149204315426, 507.7231478063112, 62.69060983494555, 71.26, 122.64, 364.2, 48.369565217391305, 13.73913043478261, 27.67391304347826, 3.857142857142857, 2.0, inf, 1.0, 2.0], [4.661441430191333, 24.88372093023256, 52.25, 23.45850795684574, 100.2768521936888, 34.30939016505445, 71.26, 122.64, 364.2, 48.369565217391305, 13.73913043478261, 27.67391304347826, 3.857142857142857, 2.0, -inf, 1.0, 2.0]-[4.767441860465116, 25.153674511868267, 57.140296159230665, 26.5, 304.0, 48.5, 84.34078816577545, 137.79947948483368, 381.6942270733086, 60.55640302418716, 13.743767536345553, 35.679500266969946, 3.857142857142857, 2.0, inf, 1.0, 2.0]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [0.8298515824439631, 0.8763440803008871, 0.5820830329762925, 0.36736824095718557, 1.0, 1.0, 0.7225526922492995]
# [0.15429914092077482, 0.16294376199561475, 0.10823009057630599, 0.06830691798445494, 0.1859358277854391, 0.1859358277854391, 0.13434843295197113]
# learnt
# core: {[-inf, -inf, -inf, -inf, -inf, -inf, 194.36629176997587, 241.0997712230266, 2987.8366911158028, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 207.44707993575133, 256.2592507078603, 3005.3309181891113, inf, inf, inf, inf, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, 207.44707993575133, 256.2592507078603, 3005.3309181891113, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 220.5278681015268, 271.418730192694, 3022.82514526242, inf, inf, inf, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# [1.0, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# known
# core: {[4.0, 10.0, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 100.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 600.0, 80.0, 150.0, 250.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, 72.20408163265306, 124.12244897959184, 370.40816326530614, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 600.0, 500.0, 12000.0, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 0.0, 26.05263157894737, 303.94736842105266, 0.0, 72.20408163265306, 124.12244897959184, 300.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 51.31578947368421, 50.0, 450.0, 47.36842105263158, 90.0, 250.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [1.0, 25.29268292682927, 51.31578947368421, 26.05263157894737, 0.0, 0.0, 60.0, 80.0, 250.0, 48.266666666666666, 0.0, 0.0, -inf, -inf, -inf, 1.0, -inf]-[4.780487804878049, 30.0, 100.0, 30.0, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, inf, inf, inf, 1.0, inf], [4.0, 10.0, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 250.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 200.0, 550.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 300.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 55.0, 70.0, 30.0, 303.94736842105266, 60.0, 100.0, 200.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [4.0, 2.0, 51.31578947368421, 26.05263157894737, 200.0, 47.36842105263158, 30.0, 70.0, 20.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 303.94736842105266, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 10.0, 303.94736842105266, 47.36842105263158, 20.0, 55.0, 80.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, 1.0, 2.0]-[5.0, 40.0, 60.0, 26.05263157894737, 800.0, 60.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, 1.0, 2.0], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 70.0, 100.0, 200.0, 0.0, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 70.0, 30.0, 500.0, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 48.266666666666666, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.0, 3.0, 51.31578947368421, 26.05263157894737, 10.0, 40.0, 72.20408163265306, 124.12244897959184, 350.0, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 90.0, 40.0, 303.94736842105266, 47.36842105263158, 120.0, 150.0, 370.40816326530614, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 100.0, 200.0, 48.266666666666666, -20.0, 26.8, 3.8536585365853657, -inf, -inf, 1.0, -inf]-[5.0, 40.0, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 80.0, 12.266666666666667, 94.0, 4.0, inf, inf, 1.0, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 120.0, 200.0, 48.266666666666666, 12.266666666666667, 26.8, 3.853658536585365 ...
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# [1.0, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# naive_small
# core: {[-inf, -inf, -inf, -inf, -inf, -inf, 207.44707993575133, 256.2592507078603, 3005.3309181891113, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 207.44707993575133, 256.2592507078603, 3005.3309181891113, inf, inf, inf, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# [1.0, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# naive_big
# core: {[-1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000, -1000000]-[1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# [1.0, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# cheated
# core: {[4.767441860465116, 24.613767348596852, 47.359703840769335, 26.5, 304.0, 48.5, 58.17921183422456, 107.48052051516632, 346.7057729266914, 36.18272741059545, 13.734493333219666, 19.668325819986578, 3.857142857142857, 2.0, -inf, 1.0, 2.0]-[4.873442290738899, 24.88372093023256, 52.25, 29.54149204315426, 507.7231478063112, 62.69060983494555, 71.26, 122.64, 364.2, 48.369565217391305, 13.73913043478261, 27.67391304347826, 3.857142857142857, 2.0, inf, 1.0, 2.0], [4.661441430191333, 24.88372093023256, 52.25, 23.45850795684574, 100.2768521936888, 34.30939016505445, 71.26, 122.64, 364.2, 48.369565217391305, 13.73913043478261, 27.67391304347826, 3.857142857142857, 2.0, -inf, 1.0, 2.0]-[4.767441860465116, 25.153674511868267, 57.140296159230665, 26.5, 304.0, 48.5, 84.34078816577545, 137.79947948483368, 381.6942270733086, 60.55640302418716, 13.743767536345553, 35.679500266969946, 3.857142857142857, 2.0, inf, 1.0, 2.0]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0909352351937368e-33, 5.326726594462926e-37, 1.336161141111856e-38, 1.7122159823210326e-38, 8.602728374462396e-35, 9.278109924077202e-35, 1.4627551622955028e-37]
# [0.85869779688868, 0.0004192777209621761, 1.0517202040479136e-05, 1.3477207852357565e-05, 0.06771386296887486, 0.07302993151267345, 0.000115136498916696]
# learnt
# core: {[-inf, -inf, -inf, -inf, -inf, -inf, 117.34878965449893, 198.1518701362159, 3993.0555387294503, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 130.42957782027437, 213.3113496210496, 4010.549765802759, inf, inf, inf, inf, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, 130.42957782027437, 213.3113496210496, 4010.549765802759, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 143.51036598604983, 228.4708291058833, 4028.0439928760675, inf, inf, inf, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 1.5685550666228267e-49, 4.464189196539868e-51, 5.671724144449993e-51, 2.6756243820893103e-47, 2.7515490907328147e-47, 4.589689895373225e-50]
# [1.0, 1.5685550666228267e-49, 4.464189196539868e-51, 5.671724144449993e-51, 2.6756243820893103e-47, 2.7515490907328147e-47, 4.589689895373225e-50]
# known
# core: {[4.0, 10.0, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 100.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 600.0, 80.0, 150.0, 250.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [-inf, -inf, -inf, -inf, -inf, -inf, 72.20408163265306, 124.12244897959184, 370.40816326530614, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 600.0, 500.0, 12000.0, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 0.0, 26.05263157894737, 303.94736842105266, 0.0, 72.20408163265306, 124.12244897959184, 300.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 51.31578947368421, 50.0, 450.0, 47.36842105263158, 90.0, 250.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [1.0, 25.29268292682927, 51.31578947368421, 26.05263157894737, 0.0, 0.0, 60.0, 80.0, 250.0, 48.266666666666666, 0.0, 0.0, -inf, -inf, -inf, 1.0, -inf]-[4.780487804878049, 30.0, 100.0, 30.0, 303.94736842105266, 47.36842105263158, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, inf, inf, inf, 1.0, inf], [4.0, 10.0, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 250.0, 48.266666666666666, 12.266666666666667, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 200.0, 550.0, 370.40816326530614, 63.0, 13.0, 32.0, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 100.0, 47.36842105263158, 72.20408163265306, 124.12244897959184, 300.0, 30.0, 10.0, 26.8, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 55.0, 70.0, 30.0, 303.94736842105266, 60.0, 100.0, 200.0, 370.40816326530614, 48.266666666666666, 12.266666666666667, 40.0, 4.0, inf, inf, inf, inf], [4.0, 2.0, 51.31578947368421, 26.05263157894737, 200.0, 47.36842105263158, 30.0, 70.0, 20.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 70.0, 30.0, 303.94736842105266, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 51.31578947368421, 10.0, 303.94736842105266, 47.36842105263158, 20.0, 55.0, 80.0, 48.266666666666666, 0.0, 0.0, 3.8536585365853657, -inf, -inf, 1.0, 2.0]-[5.0, 40.0, 60.0, 26.05263157894737, 800.0, 60.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 50.0, 12.266666666666667, 26.8, 4.0, inf, inf, 1.0, 2.0], [4.780487804878049, 25.29268292682927, 51.31578947368421, 26.05263157894737, 303.94736842105266, 47.36842105263158, 70.0, 100.0, 200.0, 0.0, 0.0, 0.0, 3.8536585365853657, -inf, -inf, -inf, -inf]-[5.0, 45.0, 70.0, 30.0, 500.0, 80.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 48.266666666666666, 12.266666666666667, 26.8, 4.0, inf, inf, inf, inf], [4.0, 3.0, 51.31578947368421, 26.05263157894737, 10.0, 40.0, 72.20408163265306, 124.12244897959184, 350.0, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[4.780487804878049, 25.29268292682927, 90.0, 40.0, 303.94736842105266, 47.36842105263158, 120.0, 150.0, 370.40816326530614, inf, inf, inf, inf, inf, inf, inf, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 100.0, 200.0, 48.266666666666666, -20.0, 26.8, 3.8536585365853657, -inf, -inf, 1.0, -inf]-[5.0, 40.0, 51.31578947368421, 40.0, 303.94736842105266, 50.0, 72.20408163265306, 124.12244897959184, 370.40816326530614, 80.0, 12.266666666666667, 94.0, 4.0, inf, inf, 1.0, inf], [4.780487804878049, 25.29268292682927, 50.0, 26.05263157894737, 100.0, 47.36842105263158, 70.0, 120.0, 200.0, 48.266666666666666, 12.266666666666667, 26.8, 3.853658536585365 ...
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 1.5685550666228267e-49, 4.464189196539868e-51, 5.671724144449993e-51, 2.6756243820893103e-47, 2.7515490907328147e-47, 4.589689895373225e-50]
# [1.0, 1.5685550666228267e-49, 4.464189196539868e-51, 5.671724144449993e-51, 2.6756243820893103e-47, 2.7515490907328147e-47, 4.589689895373225e-50]
# naive_small
# core: {[-inf, -inf, -inf, -inf, -inf, -inf, 130.42957782027437, 213.3113496210496, 4010.549765802759, -inf, -inf, -inf, -inf, -inf, -inf, -inf, -inf]-[inf, inf, inf, inf, inf, inf, 130.42957782027437, 213.3113496210496, 4010.549765802759, inf, inf, inf, inf, inf, inf, inf, inf]}
# mu: 1.0
# c: 0.05
# weights: <{'locomotion': 1.0, 'location': 1.0, 'size': 1.0, 'color': 1.0, 'n_leg': 1.0, 'n_wing': 1.0, 'n_beak': 1.0, 'n_tail': 1.0, 'n_ear': 1.0},{'locomotion': {0: 0.5, 1: 0.5}, 'location': {2: 0.25, 3: 0.25, 4: 0.25, 5: 0.25}, 'size': {6: 0.3333333333333333, 7: 0.3333333333333333, 8: 0.3333333333333333}, 'color': {9: 0.3333333333333333, 10: 0.3333333333333333, 11: 0.3333333333333333}, 'n_leg': {12: 1.0}, 'n_wing': {13: 1.0}, 'n_beak': {14: 1.0}, 'n_tail': {15: 1.0}, 'n_ear': {16: 1.0}}>
# [1.0, 1.5685550666228267e-49, 4.464189196539868e-51, 5.671724144449993e-51, 2.6756243820893103e-47, 2.7515490907328147e-47, 4.589689895373225e-50]
# [1.0, 1.5685550666228267e-49, 4.464189196539868e-51, 5.671724144449993e-51, 2.6756243820893103e-47, 2.7515490907328147e-47, 4.589689895373225e-50]
# naive_big
# ...
#    0.10506803809171199,
#    0.1761027095916172,
#    0.2805398196392079,
#    0.010666473258834807,
#    0.015552179514975352,
#    0.2707945283484902],
#   'naive_big': [0.14127625155516255,
#    0.10506803809171199,
#    0.1761027095916172,
#    0.2805398196392079,
#    0.010666473258834807,
#    0.015552179514975352,
#    0.2707945283484902],
#   'cheated': [0.17519806030771662,
#    0.13029590091309698,
#    0.21838669129282276,
#    0.10779039873779368,
#    0.013227597736356412,
#    0.019286409814725295,
#    0.3358149411974882]},
#  {'learnt': [0.12080834311485533,
#    0.1089686720031223,
#    0.16273662033482278,
#    0.2856627972571307,
#    0.039843694920183685,
#    0.006240326556247344,
#    0.2757395458136379],
#   'known': [0.12080834311485533,
#    0.1089686720031223,
#    0.16273662033482278,
#    0.2856627972571307,
#    0.039843694920183685,
#    0.006240326556247344,
#    0.2757395458136379],
#   'naive_small': [0.12080834311485533,
#    0.1089686720031223,
#    0.16273662033482278,
#    0.2856627972571307,
#    0.039843694920183685,
#    0.006240326556247344,
#    0.2757395458136379],
#   'naive_big': [0.12080834311485533,
#    0.1089686720031223,
#    0.16273662033482278,
#    0.2856627972571307,
#    0.039843694920183685,
#    0.006240326556247344,
#    0.2757395458136379],
#   'cheated': [0.16560307057026194,
#    0.14937334801889024,
#    0.22307800377703949,
#    0.020792511951565295,
#    0.05461740515201061,
#    0.0085541876697474,
#    0.377981472860485]},
#  {'learnt': [0.12819724329844864,
#    0.10818118787017576,
#    0.16651877817739344,
#    0.291880120135309,
#    0.0050799373677770125,
#    0.0184018395836599,
#    0.28174089356723603],
#   'known': [0.12819724329844864,
#    0.10818118787017576,
#    0.16651877817739344,
#    0.291880120135309,
#    0.0050799373677770125,
#    0.0184018395836599,
#    0.28174089356723603],
#   'naive_small': [0.12819724329844864,
#    0.10818118787017576,
#    0.16651877817739344,
#    0.291880120135309,
#    0.0050799373677770125,
#    0.0184018395836599,
#    0.28174089356723603],
#   'naive_big': [0.12819724329844864,
#    0.10818118787017576,
#    0.16651877817739344,
#    0.291880120135309,
#    0.0050799373677770125,
#    0.0184018395836599,
#    0.28174089356723603],
#   'cheated': [0.17260814125417062,
#    0.14565799760192844,
#    0.2242052640570568,
#    0.04656876307378454,
#    0.006839761325430975,
#    0.024776720968939854,
#    0.3793433517186888]},
#  {'learnt': [0.2793981485751011,
#    0.05028668869956057,
#    0.011426426564121746,
#    0.0021360389527771678,
#    0.29951900969014983,
#    0.14286257887298326,
#    0.2143711086453064],
#   'known': [0.2793981485751011,
#    0.05028668869956057,
#    0.011426426564121746,
#    0.0021360389527771678,
#    0.29951900969014983,
#    0.14286257887298326,
#    0.2143711086453064],
#   'naive_small': [0.2793981485751011,
#    0.05028668869956057,
#    0.011426426564121746,
#    0.0021360389527771678,
#    0.29951900969014983,
#    0.14286257887298326,
#    0.2143711086453064],
#   'naive_big': [0.2793981485751011,
#    0.05028668869956057,
#    0.011426426564121746,
#    0.0021360389527771678,
#    0.29951900969014983,
#    0.14286257887298326,
#    0.2143711086453064],
#   'cheated': [0.34872936156800044,
#    0.0627650717622877,
#    0.014261835524077346,
#    0.00266608602843385,
#    0.12569825610131502,
#    0.17831319275525567,
#    0.26756619626063]},
#  {'learnt': [0.3087296723034627,
#    0.056784087358249975,
#    0.0011741262666280035,
#    0.0008697228633355049,
#    0.33665448225782624,
#    0.074055896896089,
#    0.22173201205440865],
#   'known': [0.3087296723034627,
#    0.056784087358249975,
#    0.0011741262666280035,
#    0.0008697228633355049,
#    0.33665448225782624,
#    0.074055896896089,
#    0.22173201205440865],
#   'naive_small': [0.3087296723034627,
#    0.056784087358249975,
#    0.0011741262666280035,
#    0.0008697228633355049,
#    0.33665448225782624,
#    0.074055896896089,
#    0.22173201205440865],
#   'naive_big': [0.3087296723034627,
#    0.056784087358249975,
#    0.0011741262666280035,
#    0.0008697228633355049,
#    0.33665448225782624,
#    0.074055896896089,
#    0.22173201205440865],
#   'cheated': [0.4427140328617858,
#    0.08142758721305077,
#    0.001683680647569572,
#    0.0012471704239717246,
#    0.048771803664648096,
#    0.1061951205643684,
#    0.31796060462460557]},
#  {'learnt': [0.2725639367499903,
#    0.05972783613526605,
#    0.017485921136917937,
#    0.002839830441441226,
#    0.2850140560181118,
#    0.16661457983835343,
#    0.19575383967991927],
#   'known': [0.2725639367499903,
#    0.05972783613526605,
#    0.017485921136917937,
#    0.002839830441441226,
#    0.2850140560181118,
#    0.16661457983835343,
#    0.19575383967991927],
#   'naive_small': [0.2725639367499903,
#    0.05972783613526605,
#    0.017485921136917937,
#    0.002839830441441226,
#    0.2850140560181118,
#    0.16661457983835343,
#    0.19575383967991927],
#   'naive_big': [0.2725639367499903,
#    0.05972783613526605,
#    0.017485921136917937,
#    0.002839830441441226,
#    0.2850140560181118,
#    0.16661457983835343,
#    0.19575383967991927],
#   'cheated': [0.34431525819796477,
#    0.07545094030316758,
#    0.022089017068349797,
#    0.003587403980667339,
#    0.09679698332267275,
#    0.21047517423117099,
#    0.24728522289600666]},
#  {'learnt': [0.24798156091611204,
#    0.055445933852748035,
#    0.015279773342199978,
#    0.0027019149908489378,
#    0.2660954003289187,
#    0.1751147373941104,
#    0.23738067917506195],
#   'known': [0.24798156091611204,
#    0.055445933852748035,
#    0.015279773342199978,
#    0.0027019149908489378,
#    0.2660954003289187,
#    0.1751147373941104,
#    0.23738067917506195],
#   'naive_small': [0.24798156091611204,
#    0.055445933852748035,
#    0.015279773342199978,
#    0.0027019149908489378,
#    0.2660954003289187,
#    0.1751147373941104,
#    0.23738067917506195],
#   'naive_big': [0.24798156091611204,
#    0.055445933852748035,
#    0.015279773342199978,
#    0.0027019149908489378,
#    0.2660954003289187,
#    0.1751147373941104,
#    0.23738067917506195],
#   'cheated': [0.2952241733055629,
#    0.06600885938600012,
#    0.018190701101253846,
#    0.003216652950197066,
#    0.1262802850235319,
#    0.208475595483027,
#    0.2826037327504272]},
#  {'learnt': [0.25245116800176537,
#    0.030297512252253956,
#    0.005594601637891815,
#    0.00158769068598339,
#    0.2584748190129054,
#    0.19614505554986253,
#    0.2554491528593376],
#   'known': [0.25245116800176537,
#    0.030297512252253956,
#    0.005594601637891815,
#    0.00158769068598339,
#    0.2584748190129054,
#    0.19614505554986253,
#    0.2554491528593376],
#   'naive_small': [0.25245116800176537,
#    0.030297512252253956,
#    0.005594601637891815,
#    0.00158769068598339,
#    0.2584748190129054,
#    0.19614505554986253,
#    0.2554491528593376],
#   'naive_big': [0.25245116800176537,
#    0.030297512252253956,
#    0.005594601637891815,
#    0.00158769068598339,
#    0.2584748190129054,
#    0.19614505554986253,
#    0.2554491528593376],
#   'cheated': [0.2695349298282748,
#    0.032347791866130175,
#    0.005973197002106075,
#    0.001695132175552248,
#    0.20829466068519958,
#    0.209418495474838,
#    0.2727357929678992]},
#  {'learnt': [0.31794843687801455,
#    0.0017224767581974262,
#    4.6568113626148785e-06,
#    3.298657826507312e-06,
#    0.0006174883302542866,
#    0.3892186521737458,
#    0.29048499039059894],
#   'known': [0.31794843687801455,
#    0.0017224767581974262,
#    4.6568113626148785e-06,
#    3.298657826507312e-06,
#    0.0006174883302542866,
#    0.3892186521737458,
#    0.29048499039059894],
#   'naive_small': [0.31794843687801455,
#    0.0017224767581974262,
#    4.6568113626148785e-06,
#    3.298657826507312e-06,
#    0.0006174883302542866,
#    0.3892186521737458,
#    0.29048499039059894],
#   'naive_big': [0.31794843687801455,
#    0.0017224767581974262,
#    4.6568113626148785e-06,
#    3.298657826507312e-06,
#    0.0006174883302542866,
#    0.3892186521737458,
#    0.29048499039059894],
#   'cheated': [0.5119134543627019,
#    0.0027732768118203153,
#    7.497707535094046e-06,
#    5.311009984225166e-06,
#    0.0009941882000520897,
#    0.0166103891053128,
#    0.4676958828025937]},
#  {'learnt': [0.15951950153037797,
#    0.09278647808898208,
#    0.02064938829119102,
#    7.674271342269952e-06,
#    0.10768261941845968,
#    0.30967716919982347,
#    0.30967716919982347],
#   'known': [0.15951950153037797,
#    0.09278647808898208,
#    0.02064938829119102,
#    7.674271342269952e-06,
#    0.10768261941845968,
#    0.30967716919982347,
#    0.30967716919982347],
#   'naive_small': [0.15951950153037797,
#    0.09278647808898208,
#    0.02064938829119102,
#    7.674271342269952e-06,
#    0.10768261941845968,
#    0.30967716919982347,
#    0.30967716919982347],
#   'naive_big': [0.15951950153037797,
#    0.09278647808898208,
#    0.02064938829119102,
#    7.674271342269952e-06,
#    0.10768261941845968,
#    0.30967716919982347,
#    0.30967716919982347],
#   'cheated': [0.23107956571617475,
#    0.1344102686846237,
#    0.02991265414482504,
#    1.1116930983025397e-05,
#    0.15598878313733427,
#    9.936796204885262e-09,
#    0.4485976014492629]},
#  {'learnt': [0.3185534374141796,
#    0.005413134249765538,
#    9.395573888415894e-05,
#    0.00010240198327204198,
#    0.00507449146689189,
#    0.38446702535597566,
#    0.28629555379103117],
#   'known': [0.3185534374141796,
#    0.005413134249765538,
#    9.395573888415894e-05,
#    0.00010240198327204198,
#    0.00507449146689189,
#    0.38446702535597566,
#    0.28629555379103117],
#   'naive_small': [0.3185534374141796,
#    0.005413134249765538,
#    9.395573888415894e-05,
#    0.00010240198327204198,
#    0.00507449146689189,
#    0.38446702535597566,
#    0.28629555379103117],
#   'naive_big': [0.3185534374141796,
#    0.005413134249765538,
#    9.395573888415894e-05,
#    0.00010240198327204198,
#    0.00507449146689189,
#    0.38446702535597566,
#    0.28629555379103117],
#   'cheated': [0.4638002785635236,
#    0.007881293616928504,
#    0.00013679556629758377,
#    0.00014909293948468403,
#    0.007388244104403188,
#    0.10381012547747444,
#    0.4168341697318881]},
#  {'learnt': [0.19865000917628253,
#    0.04595951274332856,
#    0.0020003478344302176,
#    1.4948234128719934e-06,
#    0.0421972352458904,
#    0.3555957000883277,
#    0.3555957000883277],
#   'known': [0.19865000917628253,
#    0.04595951274332856,
#    0.0020003478344302176,
#    1.4948234128719934e-06,
#    0.0421972352458904,
#    0.3555957000883277,
#    0.3555957000883277],
#   'naive_small': [0.19865000917628253,
#    0.04595951274332856,
#    0.0020003478344302176,
#    1.4948234128719934e-06,
#    0.0421972352458904,
#    0.3555957000883277,
#    0.3555957000883277],
#   'naive_big': [0.19865000917628253,
#    0.04595951274332856,
#    0.0020003478344302176,
#    1.4948234128719934e-06,
#    0.0421972352458904,
#    0.3555957000883277,
#    0.3555957000883277],
#   'cheated': [0.30826920809612796,
#    0.07132092596732358,
#    0.003104181295503464,
#    2.3196980037422423e-06,
#    0.06548254564414957,
#    2.994599203647219e-08,
#    0.5518207893528997]},
#  {'learnt': [0.3654010124494048,
#    0.0015825005930378679,
#    2.221595789709504e-05,
#    2.062183206510028e-05,
#    0.005569888899746172,
#    0.4067278423570771,
#    0.2206759179107719],
#   'known': [0.3654010124494048,
#    0.0015825005930378679,
#    2.221595789709504e-05,
#    2.062183206510028e-05,
#    0.005569888899746172,
#    0.4067278423570771,
#    0.2206759179107719],
#   'naive_small': [0.3654010124494048,
#    0.0015825005930378679,
#    2.221595789709504e-05,
#    2.062183206510028e-05,
#    0.005569888899746172,
#    0.4067278423570771,
#    0.2206759179107719],
#   'naive_big': [0.3654010124494048,
#    0.0015825005930378679,
#    2.221595789709504e-05,
#    2.062183206510028e-05,
#    0.005569888899746172,
#    0.4067278423570771,
#    0.2206759179107719],
#   'cheated': [0.5420175160432966,
#    0.0023474019265181875,
#    3.295403653971328e-05,
#    3.0589390317399124e-05,
#    0.008262093544405746,
#    0.11996986798773711,
#    0.32733957707118516]},
#  {'learnt': [0.14653006352256473,
#    0.14653006352256473,
#    0.1317840505180259,
#    0.11767315085056615,
#    0.1518033537939142,
#    0.15283965889618217,
#    0.15283965889618217],
#   'known': [0.14653006352256473,
#    0.14653006352256473,
#    0.1317840505180259,
#    0.11767315085056615,
#    0.1518033537939142,
#    0.15283965889618217,
#    0.15283965889618217],
#   'naive_small': [0.14653006352256473,
#    0.14653006352256473,
#    0.1317840505180259,
#    0.11767315085056615,
#    0.1518033537939142,
#    0.15283965889618217,
#    0.15283965889618217],
#   'naive_big': [0.14653006352256473,
#    0.14653006352256473,
#    0.1317840505180259,
#    0.11767315085056615,
#    0.1518033537939142,
#    0.15283965889618217,
#    0.15283965889618217],
#   'cheated': [0.14763318794015443,
#    0.14763318794015443,
#    0.13277616231051773,
#    0.11855903135097272,
#    0.15294617719968093,
#    0.15399028393278769,
#    0.14646196932573205]},
#  {'learnt': [0.11876114473993335,
#    0.2847595619412233,
#    0.06358553756714848,
#    0.055819893624019776,
#    0.15238549339036042,
#    0.03992880679609137,
#    0.2847595619412233],
#   'known': [0.11876114473993335,
#    0.2847595619412233,
#    0.06358553756714848,
#    0.055819893624019776,
#    0.15238549339036042,
#    0.03992880679609137,
#    0.2847595619412233],
#   'naive_small': [0.11876114473993335,
#    0.2847595619412233,
#    0.06358553756714848,
#    0.055819893624019776,
#    0.15238549339036042,
#    0.03992880679609137,
#    0.2847595619412233],
#   'naive_big': [0.11876114473993335,
#    0.2847595619412233,
#    0.06358553756714848,
#    0.055819893624019776,
#    0.15238549339036042,
#    0.03992880679609137,
#    0.2847595619412233],
#   'cheated': [0.1660022197836128,
#    0.3980318604234328,
#    0.08887873559483908,
#    0.0780240563524701,
#    0.21300173740338674,
#    0.05581177729447585,
#    0.00024961314778260124]},
#  {'learnt': [0.12220055204907747,
#    0.15254547794145437,
#    0.015131500371817385,
#    0.1551981750706844,
#    0.20303883183869517,
#    0.11017790232014464,
#    0.24170756040812666],
#   'known': [0.12220055204907747,
#    0.15254547794145437,
#    0.015131500371817385,
#    0.1551981750706844,
#    0.20303883183869517,
#    0.11017790232014464,
#    0.24170756040812666],
#   'naive_small': [0.12220055204907747,
#    0.15254547794145437,
#    0.015131500371817385,
#    0.1551981750706844,
#    0.20303883183869517,
#    0.11017790232014464,
#    0.24170756040812666],
#   'naive_big': [0.12220055204907747,
#    0.15254547794145437,
#    0.015131500371817385,
#    0.1551981750706844,
#    0.20303883183869517,
#    0.11017790232014464,
#    0.24170756040812666],
#   'cheated': [0.15768745152728766,
#    0.1968445089261085,
#    0.019525670640651596,
#    0.20026754624441814,
#    0.26200107460122607,
#    0.142173438173246,
#    0.021500309887062082]},
#  {'learnt': [0.17460689062328044,
#    0.15703537377604668,
#    0.15580501033082744,
#    0.06679806783729804,
#    0.08475762439092767,
#    0.16709438667406132,
#    0.19390264636755838],
#   'known': [0.17460689062328044,
#    0.15703537377604668,
#    0.15580501033082744,
#    0.06679806783729804,
#    0.08475762439092767,
#    0.16709438667406132,
#    0.19390264636755838],
#   'naive_small': [0.17460689062328044,
#    0.15703537377604668,
#    0.15580501033082744,
#    0.06679806783729804,
#    0.08475762439092767,
#    0.16709438667406132,
#    0.19390264636755838],
#   'naive_big': [0.17460689062328044,
#    0.15703537377604668,
#    0.15580501033082744,
#    0.06679806783729804,
#    0.08475762439092767,
#    0.16709438667406132,
#    0.19390264636755838],
#   'cheated': [0.18659892284686752,
#    0.16782059110534667,
#    0.16650572608044106,
#    0.07138577098646247,
#    0.0905787930702534,
#    0.17857045879368416,
#    0.13853973711694467]},
#  {'learnt': [0.20728992121184692,
#    0.2024516355228804,
#    0.04500237361567066,
#    0.04577829044215488,
#    0.20465816702037254,
#    0.04331996425704158,
#    0.25149964793003304],
#   'known': [0.20728992121184692,
#    0.2024516355228804,
#    0.04500237361567066,
#    0.04577829044215488,
#    0.20465816702037254,
#    0.04331996425704158,
#    0.25149964793003304],
#   'naive_small': [0.20728992121184692,
#    0.2024516355228804,
#    0.04500237361567066,
#    0.04577829044215488,
#    0.20465816702037254,
#    0.04331996425704158,
#    0.25149964793003304],
#   'naive_big': [0.20728992121184692,
#    0.2024516355228804,
#    0.04500237361567066,
#    0.04577829044215488,
#    0.20465816702037254,
#    0.04331996425704158,
#    0.25149964793003304],
#   'cheated': [0.23627930623947027,
#    0.23076438887496875,
#    0.05129593158643357,
#    0.05218035996765651,
#    0.23327950262664104,
#    0.049378238175467326,
#    0.1468222725293625]}]

# %%
#This might take a while
'''testdata=sample_data(100)
serialize_testdata(testdata)'''

# %%
import warnings
warnings.filterwarnings("ignore")

testdata=deserialize_testdata('testdata.pkl')
evaluations=evaluate_on_dataset(testdata, categorical_cross_entropy)
print_evaluation(evaluations)

# %%
print_evaluation(evaluations)

# %%
import warnings
warnings.filterwarnings("ignore")

testdata=deserialize_testdata('testdata.pkl')
evaluations_ap=evaluate_on_dataset(testdata, average_precision)

# %%
print_evaluation(evaluations_ap)

# %%
import warnings
warnings.filterwarnings("ignore")
testdata=deserialize_testdata('testdata.pkl')
evaluations_ap2=evaluate_on_dataset(testdata, ap_balanced)
# Out:
# owl is inconsistent
# bat is inconsistent
# salmon is inconsistent
# spider is inconsistent
# Sea_Turtle_Dermochelys_Choriacea is inconsistent
# Sockeye_Salmon is inconsistent
# Golden_Trout is inconsistent
# thin_leg_spider is inconsistent
# little_brown_bat is inconsistent
# trachemys_turtle is inconsistent
#
#
# Example: somemammal1
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal2
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal3
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal4
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal5
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal6
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal7
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal8
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal9
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal10
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal11
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal12
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal13
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal14
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal15
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal16
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal17
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal18
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal19
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal20
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal21
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal22
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal23
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal24
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal25
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal26
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal27
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal28
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal29
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal30
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal31
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal32
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal33
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal34
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal35
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal36
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal37
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal38
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal39
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal40
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal41
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal42
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal43
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal44
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal45
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal46
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal47
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal48
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal49
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal50
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal51
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal52
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal53
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal54
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal55
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal56
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal57
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal58
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal59
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal60
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal61
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal62
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal63
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal64
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal65
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal66
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal67
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal68
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal69
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal70
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal71
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal72
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal73
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal74
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal75
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal76
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal77
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal78
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal79
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal80
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal81
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal82
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal83
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal84
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal85
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal86
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal87
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal88
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal89
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal90
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal91
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal92
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal93
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal94
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal95
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal96
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal97
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal98
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal99
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemammal100
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird1
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird2
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird3
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird4
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird5
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird6
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird7
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird8
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird9
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird10
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird11
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird12
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird13
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird14
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird15
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird16
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird17
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird18
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird19
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird20
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird21
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird22
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird23
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird24
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird25
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird26
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird27
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird28
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird29
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird30
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird31
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird32
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird33
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird34
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird35
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird36
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird37
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird38
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird39
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird40
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird41
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird42
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird43
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird44
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird45
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird46
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird47
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird48
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird49
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird50
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird51
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird52
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird53
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird54
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird55
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird56
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird57
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird58
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird59
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird60
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird61
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird62
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird63
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird64
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird65
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird66
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird67
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird68
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird69
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird70
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird71
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird72
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird73
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird74
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird75
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird76
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird77
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird78
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird79
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird80
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird81
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird82
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird83
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird84
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird85
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird86
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird87
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird88
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird89
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird90
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird91
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird92
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird93
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird94
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird95
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird96
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird97
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird98
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird99
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somebird100
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect1
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect2
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect3
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect4
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect5
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect6
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect7
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect8
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect9
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect10
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect11
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect12
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect13
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect14
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect15
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect16
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect17
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect18
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect19
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect20
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect21
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect22
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect23
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect24
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect25
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect26
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect27
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect28
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect29
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect30
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect31
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect32
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect33
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect34
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect35
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect36
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect37
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect38
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect39
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect40
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect41
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect42
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect43
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect44
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect45
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect46
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect47
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect48
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect49
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect50
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect51
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect52
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect53
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect54
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect55
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect56
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect57
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect58
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect59
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect60
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect61
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect62
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect63
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect64
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect65
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect66
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect67
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect68
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect69
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect70
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect71
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect72
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect73
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect74
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect75
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect76
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect77
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect78
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect79
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect80
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect81
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect82
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect83
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect84
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect85
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect86
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect87
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect88
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect89
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect90
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect91
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect92
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect93
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect94
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect95
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect96
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect97
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect98
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect99
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: someinsect100
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod1
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod2
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod3
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod4
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod5
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod6
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod7
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod8
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod9
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod10
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod11
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod12
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod13
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod14
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod15
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod16
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod17
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod18
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod19
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod20
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod21
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod22
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod23
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod24
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod25
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod26
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod27
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod28
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod29
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod30
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod31
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod32
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod33
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod34
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod35
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod36
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod37
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod38
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod39
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod40
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod41
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod42
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod43
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod44
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod45
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod46
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod47
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod48
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod49
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod50
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod51
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod52
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod53
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod54
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod55
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod56
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod57
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod58
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod59
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod60
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod61
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod62
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod63
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod64
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod65
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod66
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod67
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod68
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod69
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod70
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod71
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod72
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod73
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod74
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod75
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod76
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod77
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod78
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod79
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod80
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod81
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod82
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod83
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod84
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod85
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod86
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod87
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod88
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod89
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod90
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod91
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod92
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod93
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod94
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod95
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod96
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod97
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod98
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod99
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somearthropod100
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile1
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile2
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile3
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile4
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile5
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile6
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile7
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile8
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile9
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile10
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile11
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile12
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile13
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile14
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile15
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile16
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile17
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile18
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile19
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile20
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile21
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile22
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile23
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile24
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile25
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile26
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile27
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile28
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile29
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile30
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile31
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile32
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile33
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile34
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile35
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile36
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile37
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile38
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile39
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile40
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile41
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile42
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile43
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile44
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile45
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile46
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile47
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile48
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile49
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile50
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile51
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile52
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile53
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile54
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile55
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile56
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile57
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile58
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile59
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile60
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile61
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile62
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile63
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile64
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile65
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile66
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile67
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile68
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile69
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile70
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile71
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile72
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile73
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile74
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile75
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile76
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile77
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile78
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile79
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile80
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile81
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile82
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile83
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile84
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile85
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile86
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile87
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile88
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile89
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile90
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile91
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile92
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile93
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile94
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile95
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile96
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile97
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile98
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile99
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somereptile100
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish1
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish2
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish3
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish4
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish5
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish6
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish7
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish8
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish9
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish10
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish11
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish12
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish13
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish14
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish15
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish16
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish17
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish18
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish19
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish20
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish21
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish22
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish23
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish24
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish25
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish26
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish27
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish28
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish29
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish30
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish31
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish32
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish33
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish34
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish35
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish36
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish37
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish38
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish39
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish40
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish41
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish42
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish43
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish44
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish45
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish46
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish47
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish48
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish49
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish50
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish51
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish52
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish53
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish54
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish55
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish56
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish57
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish58
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish59
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish60
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish61
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish62
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish63
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish64
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish65
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish66
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish67
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish68
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish69
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish70
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish71
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish72
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish73
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish74
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish75
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish76
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish77
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish78
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish79
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish80
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish81
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish82
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish83
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish84
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish85
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish86
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish87
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish88
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish89
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish90
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish91
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish92
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish93
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish94
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish95
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish96
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish97
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish98
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish99
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somefish100
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk1
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk2
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk3
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk4
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk5
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk6
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk7
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk8
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk9
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk10
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk11
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk12
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk13
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk14
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk15
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk16
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk17
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk18
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk19
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk20
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk21
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk22
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk23
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk24
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk25
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk26
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk27
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk28
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk29
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk30
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk31
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk32
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk33
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk34
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk35
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk36
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk37
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk38
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk39
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk40
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk41
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk42
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk43
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk44
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk45
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk46
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk47
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk48
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk49
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk50
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk51
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk52
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk53
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk54
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk55
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk56
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk57
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk58
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk59
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk60
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk61
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk62
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk63
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk64
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk65
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk66
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk67
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk68
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk69
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk70
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk71
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk72
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk73
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk74
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk75
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk76
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk77
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk78
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk79
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk80
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk81
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk82
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk83
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk84
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk85
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk86
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk87
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk88
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk89
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk90
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk91
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk92
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk93
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk94
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk95
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk96
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk97
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk98
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk99
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2
#
#
# Example: somemollusk100
#
# learnt
#
# naiveBig
#
# naiveSmall
#
# known
#
# cheated:
#
# cheated2

# %%
print_evaluation(evaluations_ap2)
